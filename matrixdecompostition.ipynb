# %%
from sympy import Matrix, symbols, sin, cos, exp, I

# Define unique symbols for each theta and phi parameter
theta1, theta2, theta3, theta4, theta5, theta6, theta7, theta8, theta9, theta10 = symbols('theta1 theta2 theta3 theta4 theta5 theta6 theta7 theta8 theta9 theta10')
theta11, theta12, theta13, theta14, theta15, theta16, theta17, theta18, theta19, theta20 = symbols('theta11 theta12 theta13 theta14 theta15 theta16 theta17 theta18 theta19 theta20')
theta21, theta22, theta23, theta24, theta25, theta26, theta27, theta28, theta29, theta30 = symbols('theta21 theta22 theta23 theta24 theta25 theta26 theta27 theta28 theta29 theta30')
theta31, theta32, theta33, theta34, theta35, theta36, theta37, theta38, theta39, theta40 = symbols('theta31 theta32 theta33 theta34 theta35 theta36 theta37 theta38 theta39 theta40')
theta41, theta42, theta43, theta44, theta45, theta46, theta47, theta48 = symbols('theta41 theta42 theta43 theta44 theta45 theta46 theta47 theta48 ')


# Initialize three matrices with different thetas and phis for each element
M = Matrix([
    [0, 0, 0, 0, 0, 0, 0, 0],
    [0, I*exp(I*theta1/2) * sin(theta1/2), I*exp(I*theta1/2) * cos(theta1/2), 0, 0, 0, 0, 0],
    [0, I*exp(I*theta1/2) * cos(theta1/2), -I*exp(I*theta1/2) * sin(theta1/2), 0, 0, 0, 0, 0],
    [0, 0, 0, I*exp(I*theta2/2) * sin(theta2/2), I*exp(I*theta2/2) * cos(theta2/2), 0, 0, 0],
    [0, 0, 0, I*exp(I*theta2/2) * cos(theta2/2), -I*exp(I*theta2/2) * sin(theta2/2), 0, 0, 0],
    [0, 0, 0, 0, 0, I*exp(I*theta3/2) * sin(theta3/2), I*exp(I*theta3/2) * cos(theta3/2), 0],
    [0, 0, 0, 0, 0, I*exp(I*theta3/2) * cos(theta3/2), -I*exp(I*theta3/2) * sin(theta3/2), 0],
    [0, 0, 0, 0, 0, 0, 0, 0],
])

N = Matrix([
    [I*exp(I*theta4/2) * sin(theta4/2), I*exp(I*theta4/2) * cos(theta4/2), 0, 0, 0, 0, 0, 0],
    [I*exp(I*theta4/2) * cos(theta4/2), -I*exp(I*theta4/2) * sin(theta4/2), 0, 0, 0, 0, 0, 0],
    [0, 0, I*exp(I*theta5/2) * sin(theta5/2), I*exp(I*theta5/2) * cos(theta5/2), 0, 0, 0, 0],
    [0, 0, I*exp(I*theta5/2) * cos(theta5/2), -I*exp(I*theta5/2) * sin(theta5/2), 0, 0, 0, 0],
    [0, 0, 0, 0, I*exp(I*theta6/2) * sin(theta6/2), I*exp(I*theta6/2) * cos(theta6/2), 0, 0],
    [0, 0, 0, 0, I*exp(I*theta6/2) * cos(theta6/2), -I*exp(I*theta6/2) * sin(theta6/2), 0, 0],
    [0, 0, 0, 0, 0, 0, I*exp(I*theta7/2) * sin(theta7/2), I*exp(I*theta7/2) * cos(theta7/2)],
    [0, 0, 0, 0, 0, 0, I*exp(I*theta7/2) * cos(theta7/2), -I*exp(I*theta7/2) * sin(theta7/2)],
])

P = Matrix([
    [0, 0, 0, 0, 0, 0, 0, 0],
    [0, I*exp(I*theta22/2) * cos(theta22/2), 0, 0, 0, 0, 0, 0],
    [0, 0, I*exp(I*theta23/2) * cos(theta23/2), 0, 0, 0, 0, 0],
    [0, 0, 0, I*exp(I*theta24/2) * cos(theta24/2), 0, 0, 0, 0],
    [0, 0, 0, 0, I*exp(I*theta25/2) * cos(theta25/2), 0, 0, 0],
    [0, 0, 0, 0, 0, I*exp(I*theta26/2) * cos(theta26/2),0, 0],
    [0, 0, 0, 0, 0, 0, I*exp(I*theta27/2) * cos(theta27/2), 0],
    [0, 0, 0, 0, 0, 0, 0, 0],
])

result = N.subs({theta4: theta45, theta5: theta46, theta6: theta47, theta7: theta48}) * \
         M.subs({theta1: theta42, theta2: theta43, theta3: theta44}) * \
         N.subs({theta4: theta38, theta5: theta39, theta6: theta40, theta7: theta41}) * \
         M.subs({theta1: theta35, theta2: theta36, theta3: theta37}) * \
         N.subs({theta4: theta31, theta5: theta32, theta6: theta33, theta7: theta34}) * \
         M.subs({theta1: theta28, theta2: theta29, theta3: theta30}) * \
         P.subs({theta22: theta22, theta23: theta23, theta24: theta24, theta25: theta25, theta26: theta26, theta27: theta27}) *\
         N.subs({theta4: theta18, theta5: theta19, theta6: theta20, theta7: theta21}) * \
         M.subs({theta1: theta15, theta2: theta16, theta3: theta17}) * \
         N.subs({theta4: theta11, theta5: theta12, theta6: theta13, theta7: theta14}) * \
         M.subs({theta1: theta8, theta2: theta9, theta3: theta10}) * \
         N.subs({theta4: theta4, theta5: theta5, theta6: theta6, theta7: theta7}) * \
         M.subs({theta1: theta1, theta2: theta2, theta3: theta3}) 

# Display the resulting matrix
print("Result of multiplying the matrices in sequence MNMNMN:")
print(result)
# Out:
# Result of multiplying the matrices in sequence MNMNMN:
# ...
